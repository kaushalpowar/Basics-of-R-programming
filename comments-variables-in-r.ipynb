# %% [markdown]
# # Comments & Variables in R

# %% [markdown]
# ## Comments in R

# %% [markdown]
# #### Comment statments are types with # in the begining(just like Python).
# #### Any statement starting with # symbol will be ignored & will not be executed.
# #### It is a good practice to use # for **documentation** & **Explanation** of code.

# %%
# This is comment & it will be ignored while executing.
a <- 10
b <-20
c <- a+b
c
# Out:
# [1] 30

# %% [markdown]
# ## Variables in R

# %% [markdown]
# #### Variables in R programming can be used to store **integers**, **complex numbers**, **strings**, **vectors**, and **matrices**.
# #### R is dynamically programmed language, so declaration of variables is not required.

# %% [markdown]
# #### ⚠ Rules
# * Variable name can contain only alphabets, numbers, and either dot or underscore.
# * Variable names should start with an alphabet followed by alphanumeric characters.
# * R won't accept names starting with dot or underscore.

# %%
# Variables in R
x <- 100
name <- "R programming"
newlist <- c(1,2,3,4)
var.r <- 123

# here x, name, newlist & var.r follows the rules.
